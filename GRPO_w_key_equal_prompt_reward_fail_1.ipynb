# %% [markdown]
# <a href="https://colab.research.google.com/github/Ena-AlexBrush/Fine-Tuning-Experiments/blob/main/GRPO_w_key_equal_prompt_reward_fail_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# !pip install trl[GRPOTrainer]
# !pip install --upgrade torchao
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.12/dist-packages (5.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.29.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (1.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers[sentencepiece]) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers[sentencepiece]) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers[sentencepiece]) (0.26.8)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from transformers[sentencepiece]) (0.8.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.12/dist-packages (from transformers[sentencepiece]) (0.2.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from transformers[sentencepiece]) (5.29.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.14.1)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.6.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2026.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers[sentencepiece]) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers[sentencepiece]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers[sentencepiece]) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers[sentencepiece]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers[sentencepiece]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers[sentencepiece]) (0.1.2)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6
# Collecting trl[GRPOTrainer]
#   Downloading trl-1.9.2-py3-none-any.whl.metadata (12 kB)
# WARNING: trl 1.9.2 does not provide the extra 'grpotrainer'
# Requirement already satisfied: accelerate>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from trl[GRPOTrainer]) (1.14.0)
# Collecting datasets>=4.7.0 (from trl[GRPOTrainer])
#   Downloading datasets-5.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from trl[GRPOTrainer]) (3.1.6)
# Requirement already satisfied: packaging>20.0 in /usr/local/lib/python3.12/dist-packages (from trl[GRPOTrainer]) (26.2)
# Requirement already satisfied: transformers>=4.56.2 in /usr/local/lib/python3.12/dist-packages (from trl[GRPOTrainer]) (5.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl[GRPOTrainer]) (2.0.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl[GRPOTrainer]) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl[GRPOTrainer]) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl[GRPOTrainer]) (2.11.0+cu128)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl[GRPOTrainer]) (1.23.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl[GRPOTrainer]) (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl[GRPOTrainer]) (3.29.7)
# Collecting pyarrow>=21.0.0 (from datasets>=4.7.0->trl[GRPOTrainer])
#   Downloading pyarrow-25.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl[GRPOTrainer]) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl[GRPOTrainer]) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl[GRPOTrainer]) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl[GRPOTrainer]) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl[GRPOTrainer]) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl[GRPOTrainer]) (3.8.1)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl[GRPOTrainer]) (0.70.16)
# Requirement already satisfied: fsspec<=2026.6.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.6.0,>=2023.1.0->datasets>=4.7.0->trl[GRPOTrainer]) (2025.3.0)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.2->trl[GRPOTrainer]) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.2->trl[GRPOTrainer]) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.2->trl[GRPOTrainer]) (0.26.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->trl[GRPOTrainer]) (3.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.6.0,>=2023.1.0->datasets>=4.7.0->trl[GRPOTrainer]) (3.14.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=4.7.0->trl[GRPOTrainer]) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=4.7.0->trl[GRPOTrainer]) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=4.7.0->trl[GRPOTrainer]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=4.7.0->trl[GRPOTrainer]) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=4.7.0->trl[GRPOTrainer]) (0.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl[GRPOTrainer]) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl[GRPOTrainer]) (1.5.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl[GRPOTrainer]) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=4.7.0->trl[GRPOTrainer]) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=4.7.0->trl[GRPOTrainer]) (2.5.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (3.6.1)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (12.8.90)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=4.7.0->trl[GRPOTrainer]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=4.7.0->trl[GRPOTrainer]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=4.7.0->trl[GRPOTrainer]) (2026.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.56.2->trl[GRPOTrainer]) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.56.2->trl[GRPOTrainer]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.56.2->trl[GRPOTrainer]) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets>=4.7.0->trl[GRPOTrainer]) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets>=4.7.0->trl[GRPOTrainer]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets>=4.7.0->trl[GRPOTrainer]) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets>=4.7.0->trl[GRPOTrainer]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets>=4.7.0->trl[GRPOTrainer]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets>=4.7.0->trl[GRPOTrainer]) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets>=4.7.0->trl[GRPOTrainer]) (1.24.2)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (1.5.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=4.7.0->trl[GRPOTrainer]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers>=4.56.2->trl[GRPOTrainer]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers>=4.56.2->trl[GRPOTrainer]) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=1.4.0->trl[GRPOTrainer]) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers>=4.56.2->trl[GRPOTrainer]) (0.1.2)
# Downloading datasets-5.0.1-py3-none-any.whl (559 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.1/559.1 kB 18.0 MB/s eta 0:00:00
# Downloading trl-1.9.2-py3-none-any.whl (889 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 889.0/889.0 kB 59.1 MB/s eta 0:00:00
# Downloading pyarrow-25.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (50.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 20.1 MB/s eta 0:00:00
# Installing collected packages: pyarrow, datasets, trl
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# Successfully installed datasets-5.0.1 pyarrow-25.0.0 trl-1.9.2
# Requirement already satisfied: torchao in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Collecting torchao
#   Downloading torchao-0.18.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (21 kB)
# Downloading torchao-0.18.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 60.0 MB/s eta 0:00:00
# Installing collected packages: torchao
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
# Successfully installed torchao-0.18.0

# %%
from trl import GRPOTrainer, GRPOConfig
from datasets import load_dataset
import re
# Out:
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so

# %%
# 1. Load your dataset
train_dataset = load_dataset("hendzh/PromptShield", split="train[:50]")
eval_dataset = load_dataset("hendzh/PromptShield", split="validation[:50]")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# train.json: reconstructing file:   0%|          |  0.00B / 12.2MB
# train.json: downloading bytes:           |  0.00B
# validation.json:   0%|          | 0.00/646k [00:00<?, ?B/s]
# test.json: reconstructing file:   0%|          |  0.00B / 18.3MB
# test.json: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/18909 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/23516 [00:00<?, ? examples/s]

# %%
# 2. Define a simple reward function
def format_reward_func(completions, **kwargs):
    scores = []
    """Reward function that checks if the completion has a specific format."""
    pattern = r"^<think>.*?</think><answer>.*?</answer>$"
    completion_contents = [completion for completion in completions]
    print("completion contents")
    matches = [re.match(pattern, content, re.DOTALL) for content in completion_contents]
    print("Saved match object")
    for match in matches:
        if match:
            scores.append(1.0)
            print("It matches")

        else:
            scores.append(0.0)
            print("It does not match :( ")
    return scores

# %%
# 3. Configure training
training_args = GRPOConfig(
    output_dir="output",
    num_train_epochs=3,
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    logging_steps=10,
    num_generations=4,
)

# 4. Initialize and train
trainer = GRPOTrainer(
    model="HuggingFaceTB/SmolLM2-135M",
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    reward_funcs=format_reward_func,
)
# Out:
# Loading weights:   0%|          | 0/272 [00:00<?, ?it/s]

# %%
print(train_dataset[0].keys())
# Out:
# dict_keys(['prompt', 'quality', 'metadata', 'avg_rating', 'num_responses', 'agreement_ratio', 'raw_responses', 'kind', 'cluster_description', 'topic'])

# %%
trainer.train()
# Out:
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 0}.
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
#     <div>
#
#       <progress value='51' max='75' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [51/75 13:25 < 06:34, 0.06 it/s, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# completion contents
# Saved match object
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# It does not match :(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2954/4032920361.py in <cell line: 0>()
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1431         ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1432         with ctx:
# -> 1433             return inner_training_loop(
#    1434                 args=args,
#    1435                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1513         for epoch in range(epochs_trained, num_train_epochs):
#    1514             self.control = self.callback_handler.on_epoch_begin(self.args, self.state, self.control)
# -> 1515             self._run_epoch(
#    1516                 model=model,
#    1517                 epoch=epoch,
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1741                     sync_context = functools.partial(self.accelerator.no_sync, model=model)
#    1742                 with sync_context():
# -> 1743                     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    1744
#    1745                 if (
#
# /usr/local/lib/python3.12/dist-packages/trl/trainer/grpo_trainer.py in training_step(self, model, inputs, num_items_in_batch)
#    1543     def training_step(self, model, inputs, num_items_in_batch):
#    1544         time_before = time.perf_counter()
# -> 1545         output = super().training_step(model, inputs, num_items_in_batch)
#    1546         self._step += 1
#    1547         time_after = time.perf_counter()
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in training_step(self, model, inputs, num_items_in_batch)
#    1907                 self.optimizer.train()
#    1908
# -> 1909             inputs = self._prepare_inputs(inputs)
#    1910             if is_sagemaker_mp_enabled():
#    1911                 loss_mb = smp_forward_backward(model, inputs, self.args.gradient_accumulation_steps)
#
# /usr/local/lib/python3.12/dist-packages/trl/extras/profiling.py in wrapper(self, *args, **kwargs)
#     209         if hasattr(self, "state") and hasattr(self, "args"):
#     210             with profiling_context(self, func.__name__):
# --> 211                 return func(self, *args, **kwargs)
#     212         # For non-Trainer objects (e.g., VLLMGeneration), use ProfilingContext directly
#     213         elif hasattr(self, "accelerator"):
#
# /usr/local/lib/python3.12/dist-packages/trl/trainer/grpo_trainer.py in _prepare_inputs(self, generation_batch)
#    1572             if self._step % generate_every == 0 or self._buffered_inputs is None:
#    1573                 # self._buffered_inputs=None can occur when resuming from a checkpoint
# -> 1574                 generation_batch = self._generate_and_score_completions(generation_batch)
#    1575                 generation_batch = split_pixel_values_by_grid(generation_batch)
#    1576                 generation_batch = shuffle_sequence_dict(generation_batch)
#
# /usr/local/lib/python3.12/dist-packages/trl/trainer/grpo_trainer.py in _generate_and_score_completions(self, inputs)
#    2369             images,
#    2370             tool_images,
# -> 2371         ) = self._generate(prompts)
#    2372         if images is None:
#    2373             images = dataset_images  # restore dataset images (rollout_func path returns None)
#
# /usr/local/lib/python3.12/dist-packages/trl/trainer/grpo_trainer.py in _generate(self, prompts)
#    2170         else:
#    2171             prompt_ids, images, multimodal_fields = self._tokenize_prompts(prompts)
# -> 2172             completion_ids, logprobs = self._generate_single_turn(prompt_ids, images, multimodal_fields)
#    2173             extra_fields = {}
#    2174
#
# /usr/local/lib/python3.12/dist-packages/trl/trainer/grpo_trainer.py in _generate_single_turn(self, prompt_ids, images, multimodal_fields)
#    1859                 self._dist.summon_full_params(self.model_wrapped, recurse=False),
#    1860             ):
# -> 1861                 prompt_completion_ids = unwrapped_model.generate(
#    1862                     **generate_inputs, generation_config=self.generation_config
#    1863                 )
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2643
#    2644         # 9. Call generation mode
# -> 2645         result = decoding_method(
#    2646             self,
#    2647             input_ids,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2857                 )
#    2858                 with self._optimize_model_for_decode():
# -> 2859                     outputs = model_forward(**model_inputs, return_dict=True)
#    2860             prefill_consumed = True
#    2861             model_kwargs = self._update_model_kwargs_for_generation(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     941
#     942     def forward(*args, **kwargs):
# --> 943         return model_forward(*args, **kwargs)
#     944
#     945     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.12/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     929
#     930     def __call__(self, *args, **kwargs):
# --> 931         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     932
#     933     def __getstate__(self):
#
# /usr/local/lib/python3.12/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      42     def decorate_autocast(*args, **kwargs):
#      43         with autocast_instance:
# ---> 44             return func(*args, **kwargs)
#      45
#      46     decorate_autocast.__script_unsupported = (  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     909         if return_dict_passed is not None:
#     910             return_dict = return_dict_passed
# --> 911         output = func(self, *args, **kwargs)
#     912         if not return_dict and not isinstance(output, tuple):
#     913             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, logits_to_keep, **kwargs)
#     472         "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     473         ```"""
# --> 474         outputs: BaseModelOutputWithPast = self.model(
#     475             input_ids=input_ids,
#     476             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#    1038                     output = func(self, *args, **kwargs)
#    1039             else:
# -> 1040                 output = func(self, *args, **kwargs)
#    1041         # Restore original config value
#    1042         finally:
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/output_capturing.py in wrapper(self, *args, **kwargs)
#     250             # Run the forward
#     251             try:
# --> 252                 outputs = func(self, *args, **kwargs)
#     253             # Reset the states
#     254             finally:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, **kwargs)
#     409
#     410         for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 411             hidden_states = decoder_layer(
#     412                 hidden_states,
#     413                 attention_mask=causal_mask,
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      91
#      92             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93         return super().__call__(*args, **kwargs)
#      94
#      95
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, position_embeddings, **kwargs)
#     314         hidden_states = self.input_layernorm(hidden_states)
#     315         # Self Attention
# --> 316         hidden_states, _ = self.self_attn(
#     317             hidden_states=hidden_states,
#     318             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, position_embeddings, attention_mask, past_key_values, **kwargs)
#     265
#     266         cos, sin = position_embeddings
# --> 267         query_states, key_states = apply_rotary_pos_emb(query_states, key_states, cos, sin)
#     268
#     269         if past_key_values is not None:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in apply_rotary_pos_emb(q, k, cos, sin, unsqueeze_dim)
#     165     sin = sin.unsqueeze(unsqueeze_dim)
#     166     q_embed = (q * cos) + (rotate_half(q) * sin)
# --> 167     k_embed = (k * cos) + (rotate_half(k) * sin)
#     168     return q_embed, k_embed
#     169
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in rotate_half(x)
#     140     x1 = x[..., : x.shape[-1] // 2]
#     141     x2 = x[..., x.shape[-1] // 2 :]
# --> 142     return torch.cat((-x2, x1), dim=-1)
#     143
#     144
#
# KeyboardInterrupt:

# %% [markdown]
# **Global_step**: The total number of updates steps performed during training, each each involves processing a batch of data and updating the model's weights
#
# **training_loss**: final average loss value calculated across all the training steps.
#
# **metrics**: dictionary contain various performance metrics:
# *   **train_runtime**: the total time in secs that the training process took
# *   **train_samples_per_second**: the average number of training samples processed per seconds.
# *   **total_flos**: total floatin gpoint operations performed during training. Can be used to estimate computational cost.
# *   **train_loss**: same as training_loss, representing the final average loss
# *   **epoch**: teh number of full passes over the training dataset that were completed

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='25' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25/25 05:45]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Step</th>
#       <th>Num Tokens</th>
#       <th>Completions/mean Length</th>
#       <th>Completions/min Length</th>
#       <th>Completions/max Length</th>
#       <th>Completions/clipped Ratio</th>
#       <th>Completions/mean Terminated Length</th>
#       <th>Completions/min Terminated Length</th>
#       <th>Completions/max Terminated Length</th>
#       <th>Rewards/format Reward Func/mean</th>
#       <th>Rewards/format Reward Func/std</th>
#       <th>Reward</th>
#       <th>Reward Std</th>
#       <th>Frac Reward Zero Std</th>
#       <th>Entropy</th>
#       <th>Clip Ratio/low Mean</th>
#       <th>Clip Ratio/high Mean</th>
#       <th>Clip Ratio/region Mean</th>
#       <th>Clip Ratio/low Min</th>
#       <th>Clip Ratio/high Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>150</td>
#       <td>222202.000000</td>
#       <td>197.860000</td>
#       <td>57.720000</td>
#       <td>256.000000</td>
#       <td>0.645000</td>
#       <td>89.723334</td>
#       <td>47.480000</td>
#       <td>141.880000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>3.465615</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# {'eval_loss': 0.0,
#  'eval_num_tokens': 222202.0,
#  'eval_completions/mean_length': 197.86,
#  'eval_completions/min_length': 57.72,
#  'eval_completions/max_length': 256.0,
#  'eval_completions/clipped_ratio': 0.645,
#  'eval_completions/mean_terminated_length': 89.7233337020874,
#  'eval_completions/min_terminated_length': 47.48,
#  'eval_completions/max_terminated_length': 141.88,
#  'eval_rewards/format_reward_func/mean': 0.0,
#  'eval_rewards/format_reward_func/std': 0.0,
#  'eval_reward': 0.0,
#  'eval_reward_std': 0.0,
#  'eval_frac_reward_zero_std': 1.0,
#  'eval_entropy': 3.4656154346466064,
#  'eval_clip_ratio/low_mean': 0.0,
#  'eval_clip_ratio/high_mean': 0.0,
#  'eval_clip_ratio/region_mean': 0.0,
#  'eval_clip_ratio/low_min': 0.0,
#  'eval_clip_ratio/high_max': 0.0}

# %% [markdown]
# **eval_loss**: the average loss calcuated on the evalution dtaaset. Similar to **training_loss**
#
# **eval_num_tokens**: the total number of tokens generated or processed during evaluation.
#
# **eval_completions/mean_length**: the average length of the generated completions
# **eval_completions/max_length**: the max length among the generated completions
#
# **eval_completions/min_length**: the min length among the generated completions
# **eval_completions/clipped_ratio**: 69% of generated completions hit the 256 token cieling b4 naturally emitting and < eos > token
#
# **eval_entropy**: measure how creative or diverse the model's token predictions are.
#
# **Reward metrics**
# **eval_reward**: Average reward, the mean score assigned by the reward function, higher the values indicate the model successfully matched the required format
#
# **eval_reward_std**: Reward Variance, the variation in rewards across the generated completions.
#
# **eval_frac_reward_zero_std**: zero variance fraction, 0 is ideal, GRPO requires distinct rewards withint a sample group to calculate relative advantages
#
# **eval_completions/mean_terminated_length**: natural eos average. 31% of the responses that did complete naturally without hitting the cap and averaged around 87 tokens.
